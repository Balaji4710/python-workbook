# %%
dic = {1:"Python",2:"Java",3:"C++"}
print(dic.keys())
for i in dic.keys():
    print(dic[i])
# Out:
# dict_keys([1, 2, 3])
# Python
# Java
# C++

# %%
dic = {1:"Python",2:"Java",3:"C++"}
dic["C"]="God's language"
dic[3]= "C#"
print(dic)
# Out:
# {1: 'Python', 2: 'Java', 3: 'C#', 'C': "God's language"}

# %%
dic={1: 'Python', 2: 'Java', 3: 'C#', 'C': "God's language"}
del dic[2]
print(dic)
dic.clear()
print(dic)
# Out:
# {1: 'Python', 3: 'C#', 'C': "God's language"}
# {}

# %%
dic={1: 'Python', 2: 'Java', 3: 'C#', 'C': "God's language"}
copy = dic.copy()
print(copy)
# Out:
# {1: 'Python', 2: 'Java', 3: 'C#', 'C': "God's language"}

# %%
seq = ('java', 'python', 'c++')
dic.fromkeys(seq)
print(seq)
x=dic.fromkeys(seq,60)
print(x)
# Out:
# ('java', 'python', 'c++')
# {'java': 60, 'python': 60, 'c++': 60}

# %%
dict1 = {1:'Python',2:'Java',3:'C++',4 : 'PHP'}
print(dict1.items())
# Out:
# dict_items([(1, 'Python'), (2, 'Java'), (3, 'C++'), (4, 'PHP')])

# %%
dic = {1:'Python',2:'Java',3:'C++',4 : 'PHP'}
dic2= {1: "Python3", 5: "R"}
dic.update(dic2)
print(dic)
# Out:
# {1: 'Python3', 2: 'Java', 3: 'C++', 4: 'PHP', 5: 'R'}

# %%
student = {"Bala": [80,90,70,89,97],"Saran":[90,80,67,80,99],"Bethel": [60,70,65,80,90]}
value = []
name = []
student["Riya"] = [99,90,98,97,89]
print("Added Student", student)
student["Bala"][3] = 100
print("updated student", student)
del student["Saran"]
print("Student list after deleting",student)
for i in student.keys():
    value.append(sum(student[i])/5)
print(value)
for i in student.keys():
    name.append(i)
print(name)
# Out:
# Added Student {'Bala': [80, 90, 70, 89, 97], 'Saran': [90, 80, 67, 80, 99], 'Bethel': [60, 70, 65, 80, 90], 'Riya': [99, 90, 98, 97, 89]}
# updated student {'Bala': [80, 90, 70, 100, 97], 'Saran': [90, 80, 67, 80, 99], 'Bethel': [60, 70, 65, 80, 90], 'Riya': [99, 90, 98, 97, 89]}
# Student list after deleting {'Bala': [80, 90, 70, 100, 97], 'Bethel': [60, 70, 65, 80, 90], 'Riya': [99, 90, 98, 97, 89]}
# [87.4, 73.0, 94.6]
# ['Bala', 'Bethel', 'Riya']
