# %%
Months = {"january","Feburary", "March", "April","May", "June", "July", "August","September","October","November","December"}
print(type(Months))
# Out:
# <class 'set'>

# %%
Months = {"january","Feburary", "March", "April","May", "June", "July", "August","September","October","November","December"}
for i in Months : 
    print(i)
# Out:
# December
# September
# October
# january
# April
# March
# June
# Feburary
# August
# July
# November
# May

# %%
Months = ["january","Feburary", "March", "April","May", "June", "July", "August","September","October","November","December"]
print(type(Months))
c=set(Months)
print(c)
print(type(c))
# Out:
# <class 'list'>
# {'December', 'September', 'October', 'january', 'April', 'March', 'June', 'Feburary', 'August', 'July', 'November', 'May'}
# <class 'set'>

# %%
Months = {"january","Feburary", "March", "April","May", "June"}
Months.add("JUly")
print(Months)
# Out:
# {'March', 'June', 'JUly', 'Feburary', 'january', 'April', 'May'}

# %%
Months = {"january","Feburary", "March", "April","May", "June"}
Months.discard("january")
print(Months)
# Out:
# {'March', 'June', 'Feburary', 'April', 'May'}

# %%
Months = {"january","Feburary", "March", "April","May", "June"}
Months.update(["July", "August","September","October","November","December"])
print(Months)
# Out:
# {'December', 'September', 'April', 'March', 'June', 'Feburary', 'August', 'November', 'October', 'january', 'July', 'May'}

# %%
a = {1,3,4,2,5}
b = {6,7,8,9}
c = a.union(b)
print(c)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
a = {1,3,4,2,5,6}
b = {6,7,8,9}
print(a.intersection(b))
# Out:
# {6}
