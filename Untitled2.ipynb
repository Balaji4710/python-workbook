# %%
import numpy as np

data = [10, 20, 30, 40, 50]

print("Mean:", np.mean(data))
print("Median:", np.median(data))
print("Std Dev:", np.std(data))

# %%
favorable = 3   
total = 6

print("Probability:", favorable/total)

# %%
P_A_and_B = 0.2
P_B = 0.5

P_A_given_B = P_A_and_B / P_B
print("Conditional Probability:", P_A_given_B)

# %%
P_B_given_A = 0.8
P_A = 0.3
P_B = 0.5

P_A_given_B = (P_B_given_A * P_A) / P_B
print("Bayes Result:", P_A_given_B)

# %%
import random
trials = 1000
heads = 0

for _ in range(trials):
    if random.choice(['H', 'T']) == 'H':
        heads += 1

print("Probability of Heads:", heads/trials)

# %%
from scipy.stats import binom

n = 10   
p = 0.5  
k = 5    

prob = binom.pmf(k, n, p)
print("Binomial Probability:", prob)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
data = np.random.normal(0, 1, 1000)

plt.hist(data, bins=30)
plt.title("Normal Distribution")
plt.show()

# %%
import numpy as np
import scipy.stats as stats

data = [10, 12, 14, 16, 18]

mean = np.mean(data)
std = np.std(data)
n = len(data)

ci = stats.norm.interval(0.95, loc=mean, scale=std/np.sqrt(n))
print("Confidence Interval:", ci)

# %%
from scipy.stats import ttest_1samp

data = [10, 12, 14, 16, 18]

t_stat, p_val = ttest_1samp(data, 12)
print("T-Statistic:", t_stat)
print("P-Value:", p_val)

# %%
import matplotlib.pyplot as plt
group1 = [10, 20, 30]
group2 = [15, 25, 35]
plt.boxplot([group1, group2])
plt.xticks([1, 2], ["Group1", "Group2"])
plt.title("Group Comparison")
plt.show()

# %%
import numpy as np
A = np.array([1, 2, 3])
B = np.array([4, 5, 6])
print("Dot Product:", np.dot(A, B))

# %%
import numpy as np
A = np.array([[1, 2], [3, 4]])
print("Determinant:", np.linalg.det(A))
print("Inverse:\n", np.linalg.inv(A))

# %%
import numpy as np
x = [1, 2, 3, 4]
y = [2, 4, 6, 8]
print("Correlation:", np.corrcoef(x, y)[0,1])

# %%
x = 5
lr = 0.1

for i in range(10):
    grad = 2*x
    x = x - lr * grad

print("Minimum at:", x)

# %%
import random
trials = 10000
count = 0
for _ in range(trials):
    if random.randint(1,6) % 2 == 0:
        count += 1
print("Probability of Even Number:", count/trials)
# Out:
# Probability of Even Number: 0.5015

# %%
P_A_and_B = 0.3
P_B = 0.6

print("Conditional Probability:", P_A_and_B / P_B)
# Out:
# Conditional Probability: 0.5

# %%
P_B_given_A = 0.7
P_A = 0.4
P_B = 0.5

P_A_given_B = (P_B_given_A * P_A) / P_B
print("Bayes Result:", P_A_given_B)
# Out:
# Bayes Result: 0.5599999999999999

# %%
from scipy.stats import binom
n = 8
p = 0.5
for k in range(n+1):
    print(f"P(X={k}) =", binom.pmf(k, n, p))
# Out:
# P(X=0) = 0.003906250000000007
# P(X=1) = 0.031249999999999983
# P(X=2) = 0.10937500000000004
# P(X=3) = 0.21874999999999992
# P(X=4) = 0.27343749999999994
# P(X=5) = 0.2187499999999999
# P(X=6) = 0.10937500000000004
# P(X=7) = 0.031249999999999983
# P(X=8) = 0.00390625

# %%
import numpy as np
import scipy.stats as stats
data = [20, 22, 25, 27, 30]
mean = np.mean(data)
sem = stats.sem(data)
ci = stats.t.interval(0.95, len(data)-1, loc=mean, scale=sem)
print("Confidence Interval:", ci)
# Out:
# Confidence Interval: (np.float64(19.88012673886459), np.float64(29.71987326113541))
