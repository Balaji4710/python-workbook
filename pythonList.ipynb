# %%
mylist = ['foo','bar','baz','quz','quux','corge']
print(mylist[2])
print(mylist[1:6:1])
# Out:
# baz
# ['bar', 'baz', 'quz', 'quux', 'corge']

# %%
list1=['a','b','c',1,2,3]
for x in list1:
    print(x)
print("-------------")
# Out:
# a
# b
# c
# 1
# 2
# 3
# -------------

# %%
list1 = [1,2,3]
list2 = ['x','y','z']
list3= list1+list2
print(list3)
# Out:
# [1, 2, 3, 'x', 'y', 'z']

# %%
list2 = ['x','y','z']
print(list2*3)
# Out:
# ['x', 'y', 'z', 'x', 'y', 'z', 'x', 'y', 'z']

# %%
mylist = ['foo','bar','baz','quz','quux','corge']
mylist[1] = "car"
print (mylist)
mylist.append("VOLVO")
print(mylist)
del(mylist[3])
print(mylist)
# Out:
# ['foo', 'car', 'baz', 'quz', 'quux', 'corge']
# ['foo', 'car', 'baz', 'quz', 'quux', 'corge', 'VOLVO']
# ['foo', 'car', 'baz', 'quux', 'corge', 'VOLVO']

# %%
mylist= [1,2,34,45,65,32,51]
print("The minimum number in the list",min(mylist))
print("The maximum number in the list",max(mylist))
print("The number of elements in the list",len(mylist))
# Out:
# The minimum number in the list 1
# The maximum number in the list 65
# The number of elements in the list 7

# %%
list1 =[1,2,3,'a','b','c',1,2,3]
print(list1.count("b"))
list1.append("Balaji")
print(list1)list
list1.extend("bala")
print(list1)
# Out:
# 1
# [1, 2, 3, 'a', 'b', 'c', 1, 2, 3, 'Balaji']
# [1, 2, 3, 'a', 'b', 'c', 1, 2, 3, 'Balaji', 'b', 'a', 'l', 'a']

# %%
list1 =[1,2,3,'a','b','c',1,2,3]
list1.reverse()
print(list1)
# Out:
# [3, 2, 1, 'c', 'b', 'a', 3, 2, 1]

# %%
list1 =[1,2,3,'a','b','c',1,2,3]
list1.insert(3,"a")
print(list1)
# Out:
# [1, 2, 3, 'a', 'a', 'b', 'c', 1, 2, 3]

# %%
list1 =[1,2,3,'a','b','c',1,2,3]
list1.pop(3)
print(list1)
# Out:
# [1, 2, 3, 'b', 'c', 1, 2, 3]

# %%
list1 =[1,2,3,'a','b','c',1,2,3]
list1.remove(1)
print(list1)
# Out:
# [2, 3, 'a', 'b', 'c', 1, 2, 3]

# %%
list1 =[22,30,100,3900,399]
list1.sort()
print(list1)
# Out:
# [22, 30, 100, 399, 3900]

# %%
list1 =[1,2,3,'a','b','c',1,2,3]
for i in list1:
    if  (i == 1):
        list1.remove(1)
print(list1)
# Out:
# [2, 3, 'a', 'b', 'c', 2, 3]

# %%
size = int(input("Enter the size of the list"))
list1 = []
for i in range (size):
    item = input(f"Enter the item{i+1}")
    list1.append(item)
    print(list1)
# Out:
# Enter the size of the list 4
# Enter the item1
# ['']
# Enter the item2 0
# ['', '0']
# Enter the item3 "leam"
# ['', '0', '"leam"']
# Enter the item4 "RCB"
# ['', '0', '"leam"', '"RCB"']

# %%
user_input = input("Enter list items separated by spaces: ").strip()
print(user_input)
for i in user_input:
    print(i)
# Out:
# Enter list items separated by spaces:  4
# 4
# 4
