# %%
t1=('a','b',1,2,3.14,"ApkZube")
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t1=('a','b',1,2,3.14,"ApkZube")
print(t1[2:4])
print(t1[-1: : -1])
# Out:
# (1, 2)
# ('ApkZube', 3.14, 2, 1, 'b', 'a')

# %%
t1=('a','b',1,2,3.14,"ApkZube")
for i in t1:
    print(i)
# Out:
# a
# b
# 1
# 2
# 3.14
# ApkZube

# %%
t1 =(1,2,3)
t2 = (3,4,5,6)
t3= t1+t2
print(t3)
# Out:
# (1, 2, 3, 3, 4, 5, 6)

# %%
t2 = (3,4,5,6)
print(t2*2)
# Out:
# (3, 4, 5, 6, 3, 4, 5, 6)

# %%
t1= (1,2,3,4,5)
c=len(t1)
print(c)
# Out:
# 5

# %%
t1= (1,2,3,4,5)
c=max(t1)
d=min(t1)
print("Maximum",c)
print("Minimum",d)
# Out:
# Maximum 5
# Minimum 1
