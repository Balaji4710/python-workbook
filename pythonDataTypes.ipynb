# %%
name = input("Enter the name")
age = int(input("Enter the age"))
height= float(input("Enter the height"))
sets = {1,2,3,4,5}
tuples = (1,2,3,4,5)
lists= ['Volvo','BMW',"benz"]
print(type(name))
print(type(age))
print(type(height))
print(type(sets))
print(type(tuples))
print(type(lists))
# Out:
# Enter the name Balaji
# Enter the age 22
# Enter the height 163.5
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'set'>
# <class 'tuple'>
# <class 'list'>

# %%
tamil = int(input("Enter the marks in Tamil"))
English = int(input("Enter the marks in English"))
Maths = int(input("Enter the marks in Maths"))
science = int(input("Enter the marks in Science"))
social = int(input("Enter the marks in social"))
total = tamil + English+Maths+science+social
print("The total acqiured marks is", total)
average = total/5
print("The average is ",average)
# Out:
# Enter the marks in Tamil 92
# Enter the marks in English 96
# Enter the marks in Maths 83
# Enter the marks in Science 88
# Enter the marks in social 98
# The total acqiured marks is 457
# The average is  91.4

# %%
age = int(input("Enter the age"))
if (age >= 18):
    print("The person is eligible to vote")
else:
    print("The person is not eligble to vote")
# Out:
# Enter the age 22
# The person is eligible to vote

# %%
length = int(input("Enter the length"))
breadth = int(input("Enter the breadth"))
rectangle = length * breadth 
print("The area of rectangle is", rectangle)
# Out:
# Enter the length 12
# Enter the breadth 25
# The area of rectangle is 300

# %%
base = int(input("Enter the base"))
height = int(input("Enter the height"))
triangle = 0.5 * base * height 
print("The area of triangle  is", triangle)
# Out:
# Enter the base 12
# Enter the height 10
# The area of triangle  is 60.0

# %%
radius = int(input("Enter the radius"))
circle  =  3.14 * radius * radius
print("The area of circle is", circle)
# Out:
# Enter the radius 12
# The area of circle is 452.15999999999997

# %%
side = int(input("Enter the side"))
square  = side * side
print("The area of square is", square)
# Out:
# Enter the side 12
# The area of square is 144

# %%
length = int(input("Enter the length"))
breadth = int(input("Enter the breadth"))
rectangle = 2* (length + breadth) 
print("The perimeter of rectangle is", rectangle)
# Out:
# Enter the length 12
# Enter the breadth 32
# The perimeter of rectangle is 88

# %%
side1 = int(input("Enter the side1"))
side2 = int(input("Enter the side2"))
side3 = int(input("Enter the side3"))
triangle = side1+side2+side3 
print("The perimeter of triangle  is", triangle)
# Out:
# Enter the side1 12
# Enter the side2 20
# Enter the side3 20
# The perimeter of triangle  is 52

# %%
side = int(input("Enter the side"))
square  = 4 * side
print("The perimeter of square is", square)
# Out:
# Enter the side 13
# The perimeter of square is 52

# %%
radius = int(input("Enter the radius"))
circle  = 2*3.14 * radius
print("The perimeter of circle is", circle)
# Out:
# Enter the radius 12
# The perimeter of circle is 75.36
