# %%
def evenOdd(num):
    if (num%2==0):
        print("The number is even")
    else:
        print("The number is odd")
num = int(input("Enter the number"))
evenOdd(num)
# Out:
# Enter the number 24
# The number is even

# %%
def empData(name,age,emp_id,company="Self employee"):
    print("The name of the employee", name)
    print("The age of the employee", age)
    print("The employee_id is ",emp_id)
    print("The company name of the employee",company)
empData("Balaji",22,"MC49","Mulecraft")
empData("john doe",34,45)
# Out:
# The name of the employee Balaji
# The age of the employee 22
# The employee_id is  MC49
# The company name of the employee Mulecraft
# The name of the employee john doe
# The age of the employee 34
# The employee_id is  45
# The company name of the employee Self employee

# %%
sqr = lambda x: x*x
print(sqr(4))
# Out:
# 16

# %%
def division(dividend, divisor):
    x=dividend%divisor
    return x
print(division(divisor = 3,dividend = 10))
# Out:
# 1
