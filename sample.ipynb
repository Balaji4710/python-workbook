# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
import json

from fastjsonschema import indent

student = {
    "name": "Balaji",
    "age": 18,
    "course": "Data Science"
}
output = json.dumps(student)
print(output)
# Out:
# {"name": "Balaji", "age": 18, "course": "Data Science"}

# %%
database = {
    "python": "Python is a programming Language",
    "ai": "Ai means artificial intelligence"
}
question =input("Enter the topic").lower()
if question in database:
    print(database[question])
else:
    print("Sorry,Verified Information not available")
# Out:
# Python is a programming Language

# %%
message = "Python is easy to learn"
tone = input("Choose the tone(formal/casual)").lower()
if tone == "formal":
    print("Python is considered one of the most accessible programming languages.")
else:
    print("Python is super easy to learn")
# Out:
# Python is considered one of the most accessible programming languages.

# %%
blocked_words = ["hate", "violence"]
text = input("Enter message: ").lower()
for word in blocked_words:
    if word in text:
        print("Unsafe content detected.")
        break
else:
    print("Content is safe.")
# Out:
# Unsafe content detected.

# %%
job_description = """
Role: Data Scientist
Skills: Python, Machine Learning, SQL
Experience: 2 Years
"""
lines = job_description.split("\n")
for line in lines:
    if line.strip():
        print(line)
# Out:
# Role: Data Scientist
# Skills: Python, Machine Learning, SQL
# Experience: 2 Years

# %%
meeting_notes = """
Today team discussed project deadline.
Decision: Submit on Friday.
Action: Testing team should complete testing.
"""

print("MEETING SUMMARY")
print(meeting_notes)
# Out:
# MEETING SUMMARY
#
# Today team discussed project deadline.
# Decision: Submit on Friday.
# Action: Testing team should complete testing.

# %%
while True:
    user = input("You: ").lower()
    if user == "hello":
        print("Bot: Hi!")
    elif user == "how are you":
        print("Bot: I am fine.")
    elif user == "bye":
        print("Bot: Goodbye!")
        break
    else:
        print("Bot: I don't understand.")
# Out:
# Bot: I don't understand.
# Bot: I am fine.
# Bot: Goodbye!

# %%
import json
student = {
    "name": "Balaji",
    "age": 18,
    "course": "Data Science"
}
output = json.dumps(student ,indent=4)
print(output)
# Out:
# {
#     "name": "Balaji",
#     "age": 18,
#     "course": "Data Science"
# }

# %%
title = "AI note"
content = "Prompt Engineering"
markdown = f"#{title}\n\n{content}"
print(markdown)
# Out:
# #AI note
#
# Prompt Engineering

# %%
knowledge_base = {
    "python": "Python is a programming language.",
    "ai": "AI means Artificial Intelligence."
}
query = input("Enter topic: ").lower()
print(knowledge_base.get(query, "Verified data not found"))
# Out:
# AI means Artificial Intelligence.

# %%
user_input = input("Enter query: ")
step1 = user_input.lower()
step2 = "Processing: " + step1
step3 = "Final Output: " + step2
print(step3)
# Out:
# Final Output: Processing: explain ohms law

# %%
import json
data = {
    "name": "John",
    "skills": ["Python", "AI", "ML"]
}
with open("data.json", "w") as file:
    json.dump(data, file, indent=4)

print("JSON file created")
# Out:
# JSON file created

# %%
import json

with open("data.json", "r") as file:
    data = json.load(file)

print(data)
# Out:
# {'name': 'John', 'skills': ['Python', 'AI', 'ML']}

# %%
text = input("Enter sentence: ")
words = text.split()
for word in words:
    if len(word) > 4:
        print(word)

# %%
faq = {
    "course": "AI Course Available",
    "fees": "Course fee is 5000",
    "duration": "Course duration is 3 months"
}
question = input("Ask: ").lower()
print(faq.get(question, "Answer not found"))
# Out:
# Answer not found

# %%
name = input("Enter your name: ")
query = input("Enter your question: ")
print("Hello", name)
print("Your query is:", query)
print("Response generated")
# Out:
# Hello Balaji
# Your query is: How much amount is required for the trip
# Response generated

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
os.environ["GOOGLE_API_KEY"] = "AIzaSyAK_6VsPJi7-SAZHEcU0LYqHU-ZObEADjA"
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
prompt = ChatPromptTemplate.from_template("Explain {topic} in simple words")
chain = prompt | llm
result = chain.invoke({"topic": "Machine Learning"})
print(result.content)
# Out:
# Imagine you want to teach a computer to do something, like recognize a dog in a picture.
#
# **Traditional Programming** would be like giving the computer a super-detailed, step-by-step instruction manual: "If it has four legs AND barks AND has fur AND pointy ears, then it's a dog." You'd have to list *every single rule*.
#
# **Machine Learning** is different. It's like teaching a child:
#
# 1.  **You show the computer lots and lots of examples.** (e.g., thousands of pictures, some with dogs, some without).
# 2.  **You tell it which ones are dogs and which aren't.** (This is the "training" phase).
# 3.  **The computer then looks for patterns and relationships in all that data itself.** It figures out its *own* rules for what makes a dog a dog, without you explicitly telling it every single detail.
# ...

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
import langchainhub as hub
from langchain.agents import AgentExecutor, create_react_agent
from langchain_core.tools import Tool

os.environ["GOOGLE_API_KEY"] = "YOUR_NEW_KEY_HERE" # Remember to use your NEW key

def calculator_tool(query):
    # The agent sometimes sends extra quotes, let's strip them
    return eval(str(query).strip("'").strip('"'))

tools = [
    Tool(
        name="Calculator",
        func=calculator_tool,
        description="Useful for math calculations. Input should be a math expression like 2*2"
    )
]

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0)

# This will now work with the correct import above
prompt = hub.pull("hwchase17/react")

agent = create_react_agent(llm, tools, prompt)
agent_executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

result = agent_executor.invoke({"input": "What is 25 multiplied by 4?"})
print(result["output"])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[41], line 4
#       1 import os
#       2 from langchain_google_genai import ChatGoogleGenerativeAI
#       3 import langchainhub as hub
# ----> 4 from langchain.agents import AgentExecutor, create_react_agent
#       5 from langchain_core.tools import Tool
#       6
#       7 os.environ["GOOGLE_API_KEY"] = "YOUR_NEW_KEY_HERE" # Remember to use your NEW key
#
# ImportError: cannot import name 'AgentExecutor' from 'langchain.agents' (C:\Users\Home\PycharmProjects\promptEngineering\.venv\Lib\site-packages\langchain\agents\__init__.py)

# %%
from langchain_core.messages import HumanMessage, AIMessage
chat_history = []
chat_history.append(HumanMessage(content="My name is Menaka"))
chat_history.append(AIMessage(content="Nice to meet you"))
for msg in chat_history:
    print(f"{msg.type}: {msg.content}")
# Out:
# human: My name is Menaka
# ai: Nice to meet you

# %%
import fitz

pdf = fitz.open(r"C:\Users\Home\Downloads\BalajiMuleResume.pdf")

full_text = ""
for page in pdf:
    blocks = page.get_text("blocks")
    for b in blocks:
        full_text += b[4] + "\n" # The 4th element in the block is the text

print(full_text)
# Out:
# BALAJI S
#
# MULESOFT DEVELOPER
#
# PROFESSIONAL SUMMARY
#
# MuleSoft Developer with 1+ year of experience in designing and developing API-led integration solutions
#
# using MuleSoft Anypoint Platform. Proficient in building scalable APIs, DataWeave transformations, and
#
# implementing robust error handling and monitoring solutions. Focused on delivering reliable, high-
#
# performance integrations with strong testing practices.
#
# 6369506802
# balajisrinivasan635@gmail.com
# www.linkedin.com/in/balajisrinivasandev
#
# TECHNICAL SKILLS
#
# Integration Platforms: MuleSoft Anypoint Platform, Anypoint Studio, API Manager, Runtime Manager
#
# Languages: DataWeave 2.0, Java, SQL
#
# Tools: Git, GitHub, Jenkins, Postman
#
# Cloud & Monitoring: CloudHub, Datadog
#
# Messaging: Anypoint MQ, RabbitMQ
#
# Other Skills: RAML, CI/CD, Agile Methodology
#
# WORK EXPERIENCE
# MuleSoft Developer
# Mulecraft Private Limited
# Client: ShiftLogic | Jul 2025 – Dec 2025
#
# ...

# %%
documents = [
    "Python is a programming language",
    "AI means Artificial Intelligence"
]

question = "What is AI?"

for doc in documents:
    if "AI" in doc:
        print(doc)
# Out:
# AI means Artificial Intelligence

# %%
import time

text = "Hello, I am an AI assistant."

for word in text.split():
    print(word, end=" ", flush=True)
    time.sleep(0.3)
# Out:
# Hello, I am an AI assistant.

# %%
def student_info(name):
    data = {
        "Menaka": "AI Student",
        "Kalaivanan": "Developer"
    }
    return data.get(name, "Not found")

print(student_info("Menaka"))
# Out:
# AI Student
